# %%
import hvplot.pandas
import pandas as pd
# %store -r

# %%
#convert data to pct_change
all_data = all_data.astype(float)
all_data_pct_change = all_data.pct_change()
all_data_pct_change.dropna(inplace=True)
all_data_pct_change.head()
# Out:
#                     1         2         3         4         5         6  \
# TIME_PERIOD
# 2011-12-01  -0.007904 -0.006096 -0.003204  0.014647 -0.002055  0.018549
# 2012-03-01   0.023818 -0.009020 -0.005314 -0.015406  0.025450 -0.014510
# 2012-06-01   0.011491  0.005379  0.006289  0.004658  0.001197 -0.029103
# 2012-09-01  -0.011797 -0.012402  0.010986 -0.004264  0.018580 -0.011890
# 2012-12-01   0.035249  0.025504  0.004285  0.002842  0.027572  0.025801
#
#                     7         8       AUS      Rate
# TIME_PERIOD
# 2011-12-01  -0.091712  0.032534 -0.004147 -0.094737
# 2012-03-01  -0.013011 -0.011737  0.006276 -0.011628
# 2012-06-01  -0.009235  0.006043  0.006513 -0.167059
# 2012-09-01   0.024027 -0.011246 -0.003848 -0.011299
# 2012-12-01   0.081418  0.047792  0.024929 -0.134286

# %%
#create correlation matrix
corr_all_data = all_data_pct_change.corr()
corr_all_data.head()
# Out:
#           1         2         3         4         5         6         7  \
# 1  1.000000  0.790848  0.572350  0.425303  0.404153  0.466035  0.262408
# 2  0.790848  1.000000  0.584461  0.492025  0.327876  0.575190  0.206977
# 3  0.572350  0.584461  1.000000  0.814910  0.520879  0.748748  0.266172
# 4  0.425303  0.492025  0.814910  1.000000  0.468124  0.655494  0.261054
# 5  0.404153  0.327876  0.520879  0.468124  1.000000  0.429770  0.257357
#
#           8       AUS      Rate
# 1  0.452583  0.929533 -0.065730
# 2  0.623895  0.897716 -0.155072
# 3  0.719200  0.776752  0.052221
# 4  0.665538  0.642273  0.077910
# 5  0.463770  0.535266 -0.109088

# %%
corr_all_data.hvplot.heatmap()
# Out:
# :HeatMap   [columns,index]   (value)
