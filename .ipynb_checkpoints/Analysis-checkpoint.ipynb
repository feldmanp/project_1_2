# %%
import pandas as pd
from pathlib import Path

# %%
# Load ppty price csv

property_price_df = pd.read_csv(Path('./Resources/res_dwell_st.csv'))
property_price_df
# Out:
#                      DATAFLOW  MEASURE REGION FREQ TIME_PERIOD  OBS_VALUE  \
# 0     ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2011-Q3   253939.4
# 1     ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2011-Q4   257468.3
# 2     ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2012-Q1   253614.0
# 3     ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2012-Q2   254790.2
# 4     ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2012-Q3   254105.2
# ...                       ...      ...    ...  ...         ...        ...
# 1930  ABS:RES_DWELL_ST(1.0.0)        5      3    Q     2021-Q1      598.9
# 1931  ABS:RES_DWELL_ST(1.0.0)        5      3    Q     2021-Q2      644.6
# 1932  ABS:RES_DWELL_ST(1.0.0)        5      3    Q     2021-Q3      685.2
# 1933  ABS:RES_DWELL_ST(1.0.0)        5      3    Q     2021-Q4      744.4
# 1934  ABS:RES_DWELL_ST(1.0.0)        5      3    Q     2022-Q1      787.3
#
#      UNIT_MEASURE  UNIT_MULT OBS_STATUS  OBS_COMMENT
# ...

# %%
# Load interest rate csv
ir_df = pd.read_csv(Path('./Resources/f1.1-data.csv))
ir_df
# Out:
#   File "C:\Users\Duc L\AppData\Local\Temp\ipykernel_173308\489645808.py", line 2
#     ir_df = pd.read_csv(Path('./Resources/f1.1-data.csv))
#                                                          ^
# SyntaxError: EOL while scanning string literal
