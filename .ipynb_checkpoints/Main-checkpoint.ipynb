# %%
from Data import Data
import pandas as pd
import requests
import json
from pathlib import Path

# %%
data = Data()

# response = data.get_data_request("https://api.data.abs.gov.au/data/RPPI/all?format=json")
# # "https://api.alternative.me/v2/ticker/Bitcoin/?convert=CAD")
# #                                  "https://api.data.abs.gov.au/data/RPPI/all?format=json")
# response

csv_path = "Resources/res_dwell_st.csv"
#df = data.get_data_csv(Path(csv_path))
#df = data.load_residential_prop_df()

# %%
property_value_df = pd.read_csv(Path(csv_path))
property_value_df.head()
# Out:
#                   DATAFLOW  MEASURE REGION FREQ TIME_PERIOD  OBS_VALUE  \
# 0  ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2011-Q3   253939.4
# 1  ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2011-Q4   257468.3
# 2  ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2012-Q1   253614.0
# 3  ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2012-Q2   254790.2
# 4  ABS:RES_DWELL_ST(1.0.0)        2      4    Q     2012-Q3   254105.2
#
#   UNIT_MEASURE  UNIT_MULT OBS_STATUS  OBS_COMMENT
# 0          AUD          6        NaN          NaN
# 1          AUD          6        NaN          NaN
# 2          AUD          6        NaN          NaN
# 3          AUD          6        NaN          NaN
# 4          AUD          6        NaN          NaN

# %%
property_value_df=property_value_df[property_value_df['UNIT_MEASURE']=='AUD' ]
property_value_df=property_value_df[property_value_df['MEASURE']==1]

# %%
a= property_value_df[['REGION','TIME_PERIOD','OBS_VALUE']]
a['TIME_PERIOD']=a['TIME_PERIOD'].str.replace('Q1','Mar')
a['TIME_PERIOD']=a['TIME_PERIOD'].str.replace('Q2','Jun')
a['TIME_PERIOD']=a['TIME_PERIOD'].str.replace('Q3','Sep')
a['TIME_PERIOD']=a['TIME_PERIOD'].str.replace('Q4','Dec')
a.head()
# Out:
# C:\Users\Duc L\.conda\envs\dev\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Duc L\.conda\envs\dev\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Duc L\.conda\envs\dev\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Duc L\.conda\envs\dev\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#     REGION TIME_PERIOD  OBS_VALUE
# 129    AUS    2011-Sep  4418854.0
# 130    AUS    2011-Dec  4400528.1
# 131    AUS    2012-Mar  4428147.6
# 132    AUS    2012-Jun  4456988.8
# 133    AUS    2012-Sep  4439837.5

# %%
a['TIME_PERIOD'] = pd.to_datetime(a['TIME_PERIOD'])
a = a.set_index('TIME_PERIOD')
a.head()
# Out:
# C:\Users\Duc L\.conda\envs\dev\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             REGION  OBS_VALUE
# TIME_PERIOD
# 2011-09-01     AUS  4418854.0
# 2011-12-01     AUS  4400528.1
# 2012-03-01     AUS  4428147.6
# 2012-06-01     AUS  4456988.8
# 2012-09-01     AUS  4439837.5

# %%
# Reorganize the Property Price DataFrame
df1 = a[a['REGION'] == '1'].drop('REGION', axis=1)
df2 = a[a['REGION'] == '2'].drop('REGION', axis=1)
df3 = a[a['REGION'] == '3'].drop('REGION', axis=1)
df4 = a[a['REGION'] == '4'].drop('REGION', axis=1)
df5 = a[a['REGION'] == '5'].drop('REGION', axis=1)
df6 = a[a['REGION'] == '6'].drop('REGION', axis=1)
df7 = a[a['REGION'] == '7'].drop('REGION', axis=1)
df8 = a[a['REGION'] == '8'].drop('REGION', axis=1)
dfAUS = a[a['REGION'] == 'AUS'].drop('REGION', axis=1)

# Concatenate the Property Price DataFrames
df2 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8
# 2019-06-01    37517.9  116763.9   6720484.5
# 2019-09-01    37552.6  118153.9   6951369.8
# 2019-12-01    35261.8  125005.4   7170832.2
# 2020-03-01    35645.1  125060.8   7278072.7
# 2020-06-01    36629.4  128461.4   7251093.3
# 2020-09-01    36124.2  132392.5   7487531.1
# 2020-12-01    39517.1  140314.6   7886460.5
# 2021-03-01    38462.6  151526.6   8360913.5
# 2021-06-01    40525.4  165369.5   8807771.4
# 2021-09-01    41699.1  170962.3   9433076.1
# 2021-12-01    43280.8  185321.9   9952366.5
# 2022-03-01    44387.5  191528.8  10173551.0

# %%
df2 = df2.reset_index()

# %%
ir_path = 'Resources/RBA_Cash Rate_monthly average.csv'
ir_df = pd.read_csv(Path(ir_path))
ir_df.head(15)
# Out:
#    F1.1 INTEREST RATES AND YIELDS – MONEY MARKET  \
# 0                                          Title
# 1                                    Description
# 2                                      Frequency
# 3                                           Type
# 4                                          Units
# 5                                            NaN
# 6                                            NaN
# 7                                         Source
# 8                               Publication date
# 9                                      Series ID
# 10                                      Jun-1969
# 11                                      Jul-1969
# 12                                      Aug-1969
# 13                                      Sep-1969
# 14                                      Oct-1969
#
#                            Unnamed: 1  \
# 0                    Cash Rate Target
# 1   Cash Rate Target; monthly average
# 2                             Monthly
# 3                            Original
# 4                            Per cent
# 5                                 NaN
# 6                                 NaN
# 7                                 RBA
# 8                         02-Aug-2022
# 9                            FIRMMCRT
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
#
#                                         Unnamed: 2  \
# 0                    Interbank Overnight Cash Rate
# 1   Interbank Overnight Cash Rate; monthly average
# 2                                          Monthly
# 3                                         Original
# 4                                         Per cent
# 5                                              NaN
# 6                                              NaN
# 7                                              RBA
# 8                                      02-Aug-2022
# 9                                         FIRMMCRI
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
#
#                                            Unnamed: 3  \
# 0               Highest Interbank Overnight Cash Rate
# 1   Highest Interbank Overnight Cash Rate; monthly...
# 2                                             Monthly
# 3                                            Original
# 4                                            Per cent
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 RBA
# 8                                         02-Aug-2022
# 9                                          FIRMMCRIHM
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                            Unnamed: 4  \
# 0                Lowest Interbank Overnight Cash Rate
# 1   Lowest Interbank Overnight Cash Rate; monthly ...
# 2                                             Monthly
# 3                                            Original
# 4                                            Per cent
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 RBA
# 8                                         02-Aug-2022
# 9                                          FIRMMCRILM
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                            Unnamed: 5  \
# 0                  Volume of Cash Market Transactions
# 1   Volume of Interbank Overnight Cash Market Tran...
# 2                                             Monthly
# 3                                            Original
# 4                                                  $m
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 RBA
# 8                                         02-Aug-2022
# 9                                          FIRMMCRIVM
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                            Unnamed: 6  \
# 0                  Number of Cash Market Transactions
# 1   Number of Interbank Overnight Cash Market Tran...
# 2                                             Monthly
# 3                                            Original
# 4                                             Number
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 RBA
# 8                                         02-Aug-2022
# 9                                          FIRMMCRINM
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                            Unnamed: 7  \
# 0                                   1-month BABs/NCDs
# 1   Bank Accepted Bills/Negotiable Certificates of...
# 2                                             Monthly
# 3                                            Original
# 4                                            Per cent
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 ASX
# 8                                         02-Aug-2022
# 9                                          FIRMMBAB30
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                            Unnamed: 8  \
# 0                                   3-month BABs/NCDs
# 1   Bank Accepted Bills/Negotiable Certificates of...
# 2                                             Monthly
# 3                                            Original
# 4                                            Per cent
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 ASX
# 8                                         02-Aug-2022
# 9                                          FIRMMBAB90
# 10                                               5.90
# 11                                               5.80
# 12                                               6.10
# 13                                               5.80
# 14                                               5.60
#
#                                            Unnamed: 9  ...  \
# 0                                   6-month BABs/NCDs  ...
# 1   Bank Accepted Bills/Negotiable Certificates of...  ...
# 2                                             Monthly  ...
# 3                                            Original  ...
# 4                                            Per cent  ...
# 5                                                 NaN  ...
# 6                                                 NaN  ...
# 7                                                 ASX  ...
# 8                                         02-Aug-2022  ...
# 9                                         FIRMMBAB180  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
#
#                                           Unnamed: 11  \
# 0                                         3-month OIS
# 1   Overnight Indexed Swaps-3 months; monthly average
# 2                                             Monthly
# 3                                            Original
# 4                                            Per cent
# 5                                                 NaN
# 6                                                 NaN
# 7                                              FENICS
# 8                                         02-Aug-2022
# 9                                           FIRMMOIS3
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                           Unnamed: 12  \
# 0                                         6-month OIS
# 1   Overnight Indexed Swaps-6 months; monthly average
# 2                                             Monthly
# 3                                            Original
# 4                                            Per cent
# 5                                                 NaN
# 6                                                 NaN
# 7                                              FENICS
# 8                                         12-Apr-2022
# 9                                           FIRMMOIS6
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                 Unnamed: 13  \
# 0                     1-month Treasury Note
# 1   Treasury Notes-1 month; monthly average
# 2                                 See notes
# 3                                  Original
# 4                                  Per cent
# 5                                       NaN
# 6                                       NaN
# 7                                       RBA
# 8                               12-Apr-2022
# 9                                  FIRMMTN1
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
#
#                                  Unnamed: 14  \
# 0                     3- month Treasury Note
# 1   Treasury Notes-3 months; monthly average
# 2                                  See notes
# 3                                   Original
# 4                                   Per cent
# 5                                        NaN
# 6                                        NaN
# 7                                        RBA
# 8                                12-Apr-2022
# 9                                   FIRMMTN3
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
#
#                                  Unnamed: 15 Unnamed: 16  Unnamed: 17  \
# 0                     6- month Treasury Note         NaN          NaN
# 1   Treasury Notes-6 months; monthly average         NaN          NaN
# 2                                  See notes         NaN          NaN
# 3                                   Original         NaN          NaN
# 4                                   Per cent         NaN          NaN
# 5                                        NaN         NaN          NaN
# 6                                        NaN         NaN          NaN
# 7                                        RBA         NaN          NaN
# 8                                12-Apr-2022         NaN          NaN
# 9                                   FIRMMTN6         NaN          NaN
# 10                                       NaN         NaN          NaN
# 11                                       NaN         NaN          NaN
# 12                                       NaN         NaN          NaN
# 13                                       NaN         NaN          NaN
# 14                                       NaN         NaN          NaN
#
#     Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# 5           NaN          NaN          NaN
# 6           NaN          NaN          NaN
# 7           NaN          NaN          NaN
# 8           NaN          NaN          NaN
# 9           NaN          NaN          NaN
# 10          NaN          NaN          NaN
# 11          NaN          NaN          NaN
# 12          NaN          NaN          NaN
# 13          NaN          NaN          NaN
# 14          NaN          NaN          NaN
#
# [15 rows x 21 columns]

# %%
ir_df = ir_df.iloc[10:,0:2].dropna()
ir_df.rename({'F1.1 INTEREST RATES AND YIELDS – MONEY MARKET': 'TIME_PERIOD', 'Unnamed: 1': 'rate'}, axis=1, inplace=True)

# %%
display(ir_df.head())
display(ir_df.tail())
# Out:
#     TIME_PERIOD   rate
# 264    Aug-1990  14.00
# 265    Sep-1990  14.00
# 266    Oct-1990  13.43
# 267    Nov-1990  13.00
# 268    Dec-1990  12.58
#     TIME_PERIOD  rate
# 643    Mar-2022  0.10
# 644    Apr-2022  0.10
# 645    May-2022  0.33
# 646    Jun-2022  0.73
# 647    Jul-2022  1.28

# %%
ir_df['TIME_PERIOD'] = pd.to_datetime(ir_df['TIME_PERIOD'])

# %%
ir_df.reset_index().drop('index', axis=1)
# Out:
#     TIME_PERIOD   rate
# 0    1990-08-01  14.00
# 1    1990-09-01  14.00
# 2    1990-10-01  13.43
# 3    1990-11-01  13.00
# 4    1990-12-01  12.58
# ..          ...    ...
# 379  2022-03-01   0.10
# 380  2022-04-01   0.10
# 381  2022-05-01   0.33
# 382  2022-06-01   0.73
# 383  2022-07-01   1.28
#
# [384 rows x 2 columns]

# %%
df2.tail()
# Out:
#    TIME_PERIOD          1          2          3         4         5         6  \
#                 OBS_VALUE  OBS_VALUE  OBS_VALUE OBS_VALUE OBS_VALUE OBS_VALUE
# 38  2021-03-01  3345366.1  2342460.2  1273828.2  415496.9  656976.9  136796.0
# 39  2021-06-01  3494937.8  2490073.5  1376139.1  436067.6  661255.1  143403.5
# 40  2021-09-01  3866154.6  2591893.5  1468566.0  461574.7  678167.0  154058.9
# 41  2021-12-01  4042739.0  2713519.1  1601077.2  499456.4  697347.9  169624.2
# 42  2022-03-01  4078843.1  2736187.6  1700675.1  529124.4  717816.5  174987.9
#
#            7         8         AUS
#    OBS_VALUE OBS_VALUE   OBS_VALUE
# 38   38462.6  151526.6   8360913.5
# 39   40525.4  165369.5   8807771.4
# 40   41699.1  170962.3   9433076.1
# 41   43280.8  185321.9   9952366.5
# 42   44387.5  191528.8  10173551.0

# %%
# Concatenate the Property Price DataFrames

# %%
df3.plot()
# Out:
# <AxesSubplot:xlabel='TIME_PERIOD'>

# %%
df4 = df2.merge(ir_df, how='outer', on = 'TIME_PERIOD')
df4.head()
# Out:
# C:\Users\Duc L\.conda\envs\dev\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left,1 on the right)
#   validate=validate,
#   TIME_PERIOD (TIME_PERIOD, )  (1, OBS_VALUE)  (2, OBS_VALUE)  (3, OBS_VALUE)  \
# 0  2011-09-01      2011-09-01       1535219.2       1161369.3        765191.3
# 1  2011-12-01      2011-12-01       1523085.2       1154289.4        762739.5
# 2  2012-03-01      2012-03-01       1559361.3       1143877.6        758686.5
# 3  2012-06-01      2012-06-01       1577280.7       1150030.9        763457.8
# 4  2012-09-01      2012-09-01       1558673.2       1135768.6        771845.0
#
#    (4, OBS_VALUE)  (5, OBS_VALUE)  (6, OBS_VALUE)  (7, OBS_VALUE)  \
# 0        274405.0        494352.4         70315.2         38687.4
# 1        278424.3        493336.4         71619.5         35139.3
# 2        274134.8        505891.6         70580.3         34682.1
# 3        275411.8        506497.2         68526.2         34361.8
# 4        274237.4        515907.8         67711.4         35187.4
#
#    (8, OBS_VALUE)  (AUS, OBS_VALUE)  rate
# 0         79314.2         4418854.0  4.75
# 1         81894.6         4400528.1  4.30
# 2         80933.4         4428147.6  4.25
# 3         81422.5         4456988.8  3.54
# 4         80506.8         4439837.5  3.50
